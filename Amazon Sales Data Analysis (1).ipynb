# %% [markdown]
# # Project Amazon Sales Data Analysis

# %% [markdown]
# # Import Python Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset=pd.read_csv(r"C:\Users\DELL\OneDrive\Pictures\Screenshots\Amazon Sales data.csv")

# %%
dataset.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H   5/28/2010  669165933   6/27/2010        9925
# 1        Online              C   8/22/2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C   6/20/2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %%
dataset.shape
# Out:
# (100, 14)

# %%
dataset.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
dataset['Country'].unique()
# Out:
# ['Tuvalu', 'Grenada', 'Russia', 'Sao Tome and Principe', 'Rwanda', ..., 'Slovenia', 'Romania', 'Nicaragua', 'Malaysia', 'Mozambique']
# Length: 76
# Categories (76, object): ['Tuvalu' < 'Grenada' < 'Russia' < 'Sao Tome and Principe' ... 'Romania' < 'Nicaragua' < 'Malaysia' < 'Mozambique']

# %%
countries = ['Tuvalu', 'Grenada', 'Russia', 'Sao Tome and Principe', 'Rwanda',
       'Solomon Islands', 'Angola', 'Burkina Faso',
       'Republic of the Congo', 'Senegal', 'Kyrgyzstan', 'Cape Verde',
       'Bangladesh', 'Honduras', 'Mongolia', 'Bulgaria', 'Sri Lanka',
       'Cameroon', 'Turkmenistan', 'East Timor', 'Norway', 'Portugal',
       'New Zealand', 'Moldova ', 'France', 'Kiribati', 'Mali',
       'The Gambia', 'Switzerland', 'South Sudan', 'Australia', 'Myanmar',
       'Djibouti', 'Costa Rica', 'Syria', 'Brunei', 'Niger', 'Azerbaijan',
       'Slovakia', 'Comoros', 'Iceland', 'Macedonia', 'Mauritania',
       'Albania', 'Lesotho', 'Saudi Arabia', 'Sierra Leone',
       "Cote d'Ivoire", 'Fiji', 'Austria', 'United Kingdom', 'San Marino',
       'Libya', 'Haiti', 'Gabon', 'Belize', 'Lithuania', 'Madagascar',
       'Democratic Republic of the Congo', 'Pakistan', 'Mexico',
       'Federated States of Micronesia', 'Laos', 'Monaco', 'Samoa ',
       'Spain', 'Lebanon', 'Iran', 'Zambia', 'Kenya', 'Kuwait',
       'Slovenia', 'Romania', 'Nicaragua', 'Malaysia', 'Mozambique']

# %%
dataset['Country'] = pd.Categorical(dataset['Country'],categories=countries,ordered=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Country', y='Total Revenue', data=dataset, ci=None)
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14904\346469947.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Country', y='Total Revenue', data=dataset, ci=None)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # Lithuania is the Country which has maximum of the Total Revenue

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Country', y='Total Profit', data=dataset, ci=None)
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14904\761980149.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Country', y='Total Profit', data=dataset, ci=None)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # Pakistan is the Country which has the maximum of the Total Profit

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Country', y='Total Cost', data=dataset, ci=None)
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14904\660651021.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Country', y='Total Cost', data=dataset, ci=None)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # Lithuania is the Country which has  maximum of the Total Cost

# %%
dataset['Region'].value_counts()
# Out:
# Region
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: count, dtype: int64

# %%
x=dataset['Region'].value_counts().index
y=dataset['Region'].value_counts().values

# %%
plt.figure(figsize=(10,8))
plt.pie(y,labels=x,startangle=90,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# # Sub-Saharan Africa is the region where total profit is maximum and North America is the region where total profit is minimum

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# H    30
# L    27
# C    22
# M    21
# Name: count, dtype: int64

# %%
sns.countplot(x="Order Priority",data=dataset)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x="Region",data=dataset,hue="Item Type")
plt.show()

# %%
dataset['Order Date'].value_counts()
# Out:
# Order Date
# 5/28/2010     1
# 10/30/2010    1
# 5/20/2017     1
# 5/26/2011     1
# 8/14/2015     1
#              ..
# 9/17/2012     1
# 5/26/2012     1
# 7/18/2014     1
# 05-07-2010    1
# 02-10-2012    1
# Name: count, Length: 100, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(x="Region",y="Total Profit",data=dataset,estimator='sum')
mp.xticks(rotation=60)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 plt.figure(figsize=(15,10))
#       2 sns.barplot(x="Region",y="Total Profit",data=dataset,estimator='sum')
# ----> 3 mp.xticks(rotation=60)
#       4 plt.show()
#
# NameError: name 'mp' is not defined

# %%
dataset['Country'].value_counts()
# Out:
# Country
# The Gambia               4
# Sierra Leone             3
# Sao Tome and Principe    3
# Mexico                   3
# Australia                3
#                         ..
# Comoros                  1
# Iceland                  1
# Macedonia                1
# Mauritania               1
# Mozambique               1
# Name: count, Length: 76, dtype: int64

# %%
dataset.plot.bar(x='Item Type',y='Total Profit',color='blue')
plt.locator_params(nbins=28)
plt.xlabel('Total Profit')
# Out:
# Text(0.5, 0, 'Total Profit')

# %%
dataset['Item Type'].unique()
# Out:
# array(['Baby Food', 'Cereal', 'Office Supplies', 'Fruits', 'Household',
#        'Vegetables', 'Personal Care', 'Clothes', 'Cosmetics', 'Beverages',
#        'Meat', 'Snacks'], dtype=object)

# %%
items = ['Baby Food', 'Cereal', 'Office Supplies', 'Fruits', 'Household',
       'Vegetables', 'Personal Care', 'Clothes', 'Cosmetics', 'Beverages',
       'Meat', 'Snacks']

# %%
dataset['Item Type'] = pd.Categorical(dataset['Item Type'],categories=items,ordered=True)

# %%
dataset.groupby('Item Type')['Total Revenue'].count().plot(kind='bar',color=['green','orange','blue','red','purple','pink','yellow','brown','aqua','grey'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14904\494749687.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dataset.groupby('Item Type')['Total Revenue'].count().plot(kind='bar',color=['green','orange','blue','red','purple','pink','yellow','brown','aqua','grey'])
# <Axes: xlabel='Item Type'>

# %%
pd.pivot_table(dataset,values='Total Cost',index='Item Type',aggfunc='count').plot(kind='bar')
# Out:
# <Axes: xlabel='Item Type'>

# %%
pd.pivot_table(dataset,values='Total Profit',index='Item Type',aggfunc='count').plot(kind='bar')
# Out:
# <Axes: xlabel='Item Type'>

# %% [markdown]
# # Cosmetics and Clothes has maximum  Revenue,Cost and Profit

# %%
dataset.loc[:,'Order Priority'].unique()
# Out:
# array(['H', 'C', 'L', 'M'], dtype=object)

# %%
dataset['Order Date'].unique()
# Out:
# array(['5/28/2010', '8/22/2012', '05-02-2014', '6/20/2014', '02-01-2013',
#        '02-04-2015', '4/23/2011', '7/17/2012', '7/14/2015', '4/18/2014',
#        '6/24/2011', '08-02-2014', '1/13/2017', '02-08-2017', '2/19/2014',
#        '4/23/2012', '11/19/2016', '04-01-2015', '12/30/2010', '7/31/2012',
#        '5/14/2014', '7/31/2015', '6/30/2016', '09-08-2014', '05-07-2016',
#        '5/22/2017', '10/13/2014', '05-07-2010', '7/18/2014', '5/26/2012',
#        '9/17/2012', '12/29/2013', '10/27/2015', '1/16/2015', '2/25/2017',
#        '05-08-2017', '11/22/2011', '1/14/2017', '04-01-2012', '2/16/2012',
#        '03-11-2017', '02-06-2010', '06-07-2012', '10-06-2012',
#        '11/14/2015', '3/29/2016', '12/31/2016', '12/23/2010',
#        '10/14/2014', '01-11-2012', '02-02-2010', '8/18/2013', '3/25/2013',
#        '11/26/2011', '9/17/2013', '06-08-2012', '6/30/2010', '2/23/2015',
#        '01-05-2012', '04-07-2014', '06-09-2013', '6/26/2013',
# ...

# %%
order_dates = ['5/28/2010', '8/22/2012', '05-02-2014', '6/20/2014', '02-01-2013',
       '02-04-2015', '4/23/2011', '7/17/2012', '7/14/2015', '4/18/2014',
       '6/24/2011', '08-02-2014', '1/13/2017', '02-08-2017', '2/19/2014',
       '4/23/2012', '11/19/2016', '04-01-2015', '12/30/2010', '7/31/2012',
       '5/14/2014', '7/31/2015', '6/30/2016', '09-08-2014', '05-07-2016',
       '5/22/2017', '10/13/2014', '05-07-2010', '7/18/2014', '5/26/2012',
       '9/17/2012', '12/29/2013', '10/27/2015', '1/16/2015', '2/25/2017',
       '05-08-2017', '11/22/2011', '1/14/2017', '04-01-2012', '2/16/2012',
       '03-11-2017', '02-06-2010', '06-07-2012', '10-06-2012',
       '11/14/2015', '3/29/2016', '12/31/2016', '12/23/2010',
       '10/14/2014', '01-11-2012', '02-02-2010', '8/18/2013', '3/25/2013',
       '11/26/2011', '9/17/2013', '06-08-2012', '6/30/2010', '2/23/2015',
       '01-05-2012', '04-07-2014', '06-09-2013', '6/26/2013',
       '11-07-2011', '10/30/2010', '10/13/2013', '10-11-2013',
       '07-08-2012', '7/25/2016', '10/24/2010', '4/25/2015', '4/23/2013',
       '8/14/2015', '5/26/2011', '5/20/2017', '07-05-2013', '11-06-2014',
       '10/28/2014', '9/15/2011', '5/29/2012', '7/20/2013', '10/21/2012',
       '9/18/2012', '11/15/2016', '01-04-2011', '3/18/2012', '2/17/2012',
       '1/16/2011', '02-03-2014', '4/30/2012', '10/23/2016', '12-06-2016',
       '07-07-2014', '6/13/2012', '11/26/2010', '02-08-2011', '7/26/2011',
       '11-11-2011', '06-01-2016', '7/30/2015', '02-10-2012']

# %%
dataset['Order Date'] = pd.Categorical(dataset['Order Date'],categories=order_dates,ordered=True)

# %%
pd.pivot_table(dataset,values='Total Profit',index='Order Date',aggfunc='count').plot(kind='hist',color='purple',stacked=False,legend=None)
mp.xticks(rotation=90)
mp.ylabel('Total Profit')
mp.locator_params(nbins=32)
mp.xlabel('Order Date')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 pd.pivot_table(dataset,values='Total Profit',index='Order Date',aggfunc='count').plot(kind='hist',color='purple',stacked=False,legend=None)
# ----> 2 mp.xticks(rotation=90)
#       3 mp.ylabel('Total Profit')
#       4 mp.locator_params(nbins=32)
#
# NameError: name 'mp' is not defined

# %%
dataset.groupby('Order Priority')['Total Profit'].sum().plot(kind='bar',color=['brown','red','purple','aqua'])
mp.ylabel('Total Profit')
mp.title('Distribution of profit on the basis of order priority')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 dataset.groupby('Order Priority')['Total Profit'].sum().plot(kind='bar',color=['brown','red','purple','aqua'])
# ----> 2 mp.ylabel('Total Profit')
#       3 mp.title('Distribution of profit on the basis of order priority')
#
# NameError: name 'mp' is not defined

# %%
dataset.groupby('Order Priority')['Total Revenue'].sum().plot(kind='bar',color=['blue'])
mp.ylabel('Total Revenue')
mp.title('Distribution of  on the basis of order priority')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 dataset.groupby('Order Priority')['Total Revenue'].sum().plot(kind='bar',color=['blue'])
# ----> 2 mp.ylabel('Total Revenue')
#       3 mp.title('Distribution of  on the basis of order priority')
#
# NameError: name 'mp' is not defined

# %%
dataset.groupby('Unit Price')['Total Profit'].sum().plot(kind='area',color=['purple'])
mp.ylabel('Total Profit')
mp.title('Distribution of profit on the basis of Unit Price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 dataset.groupby('Unit Price')['Total Profit'].sum().plot(kind='area',color=['purple'])
# ----> 2 mp.ylabel('Total Profit')
#       3 mp.title('Distribution of profit on the basis of Unit Price')
#
# NameError: name 'mp' is not defined

# %% [markdown]
# # Maximum Profit generated in the unit Price range of ₹400-₹500

# %%
dataset.groupby('Units Sold')['Total Profit'].sum().plot(kind='area',color=['Green'])
mp.ylabel('Total Profit')
mp.title('Distribution of profit on the basis of Unit Sold')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 dataset.groupby('Units Sold')['Total Profit'].sum().plot(kind='area',color=['Green'])
# ----> 2 mp.ylabel('Total Profit')
#       3 mp.title('Distribution of profit on the basis of Unit Sold')
#
# NameError: name 'mp' is not defined

# %%
dataset.groupby('Units Sold')['Total Cost'].sum().plot(kind='area',color=['aqua'])
mp.ylabel('Total Cost')
mp.title('Distribution of profit on the basis of Unit Sold')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 dataset.groupby('Units Sold')['Total Cost'].sum().plot(kind='area',color=['aqua'])
# ----> 2 mp.ylabel('Total Cost')
#       3 mp.title('Distribution of profit on the basis of Unit Sold')
#
# NameError: name 'mp' is not defined

# %%
dataset.groupby('Units Sold')['Total Revenue'].sum().plot(kind='area',color=['yellow'])
mp.ylabel('Total Revenue')
mp.title('Distribution of profit on the basis of Unit Sold')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 dataset.groupby('Units Sold')['Total Revenue'].sum().plot(kind='area',color=['yellow'])
# ----> 2 mp.ylabel('Total Revenue')
#       3 mp.title('Distribution of profit on the basis of Unit Sold')
#
# NameError: name 'mp' is not defined

# %%
bar_plot = dataset.plot.bar(x='Units Sold',y=['Total Revenue','Total Cost','Total Profit'],color=['purple','red','blue'],stacked=True,rot=True)
mp.xticks(rotation=90)
mp.locator_params(nbins=38)
mp.tick_params(axis='y', which='major', labelsize=7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 bar_plot = dataset.plot.bar(x='Units Sold',y=['Total Revenue','Total Cost','Total Profit'],color=['purple','red','blue'],stacked=True,rot=True)
# ----> 2 mp.xticks(rotation=90)
#       3 mp.locator_params(nbins=38)
#       4 mp.tick_params(axis='y', which='major', labelsize=7)
#
# NameError: name 'mp' is not defined
